# %%
# !nvidia-smi
# Out:
# Tue May 19 20:59:02 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8             10W /   70W |       3MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import torch
print(torch.cuda.is_available())      # True
print(torch.cuda.get_device_name(0))
# Out:
# True
# Tesla T4

# %%
# !git clone https://github.com/caltinuzengi/Time-Series-Library.git
# %cd Time-Series-Library/
# Out:
# Cloning into 'Time-Series-Library'...
# remote: Enumerating objects: 126, done.
# remote: Counting objects: 100% (126/126), done.
# remote: Compressing objects: 100% (88/88), done.
# remote: Total 126 (delta 48), reused 97 (delta 22), pack-reused 0 (from 0)
# Receiving objects: 100% (126/126), 175.55 KiB | 6.50 MiB/s, done.
# Resolving deltas: 100% (48/48), done.
# /content/Time-Series-Library

# %%
# !git pull
# Out:
# remote: Enumerating objects: 31, done.
# remote: Counting objects: 100% (31/31), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 20 (delta 8), reused 20 (delta 8), pack-reused 0 (from 0)
# Unpacking objects: 100% (20/20), 11.40 KiB | 1.90 MiB/s, done.
# From https://github.com/caltinuzengi/Time-Series-Library
#    e3d3134..33d94f0  main       -> origin/main
# Updating e3d3134..33d94f0
# Fast-forward
#  exp/exp_forecasting.py              |   3 +-
#  layers/PatchEmbedding.py            | 106 ++++++++++++++++++
#  models/PatchTST.py                  | 210 ++++++++++++++++++++++++++++++++++++
#  notebooks/01_experiments.ipynb      | 192 +++++++++++++++++++++++++++++----
#  pyproject.toml                      |   1 +
#  scripts/PatchTST/debug_ETTh1.sh     |  28 +++++
#  scripts/PatchTST/forecast_ETTh1.sh  |  30 ++++++
#  scripts/TimeMixer/debug_ETTh1.sh    |  28 +++++
#  scripts/TimeMixer/forecast_ETTh1.sh |   5 +-
#  scripts/checks/check_patchTST.py    |  67 ++++++++++++
#  10 files changed, 648 insertions(+), 22 deletions(-)
#  create mode 100644 layers/PatchEmbedding.py
#  create mode 100644 models/PatchTST.py
#  create mode 100644 scripts/PatchTST/debug_ETTh1.sh
#  create mode 100644 scripts/PatchTST/forecast_ETTh1.sh
#  create mode 100644 scripts/TimeMixer/debug_ETTh1.sh
#  create mode 100644 scripts/checks/check_patchTST.py

# %%
# !uv sync
# Out:
# Resolved 160 packages in 1ms
# Prepared 1 package in 933ms
# Uninstalled 1 package in 0.46ms
# Installed 1 package in 3ms==0.1.0 (from file:///content/Time
#  ~ time-series-library==0.1.0 (from file:///content/Time-Series-Library)

# %%
# !uv run download-data
# Out:
# ============================================================
# ETT Dataset Downloader
# Source : github.com/zhouhaoyi/ETDataset (Informer AAAI 2021)
# Dest   : /content/Time-Series-Library/data
# ============================================================
#
# [ETTh1]
#   Downloading ETTh1: Hourly ETT — station 1 (17,420 rows)
#   Source: https://raw.githubusercontent.com/zhouhaoyi/ETDataset/main/ETT-small/ETTh1.csv
#   [████████████████████] 100%  (2536 / 2529 KB)
#   ✓ Saved → data/ETTh1.csv  (2529 KB, 0.4s)
#   ✓ ETTh1 verified: shape=(17420, 8), columns=['date', 'HUFL', 'HULL', 'MUFL', 'MULL', 'LUFL', 'LULL', 'OT']
#
# [ETTh2]
#   Downloading ETTh2: Hourly ETT — station 2 (17,420 rows)
#   Source: https://raw.githubusercontent.com/zhouhaoyi/ETDataset/main/ETT-small/ETTh2.csv
#   [████████████████████] 100%  (2368 / 2361 KB)
#   ✓ Saved → data/ETTh2.csv  (2361 KB, 0.3s)
#   ✓ ETTh2 verified: shape=(17420, 8), columns=['date', 'HUFL', 'HULL', 'MUFL', 'MULL', 'LUFL', 'LULL', 'OT']
#
# [ETTm1]
#   Downloading ETTm1: 15-min ETT — station 1 (69,680 rows)
#   Source: https://raw.githubusercontent.com/zhouhaoyi/ETDataset/main/ETT-small/ETTm1.csv
#   [████████████████████] 100%  (10120 / 10118 KB)
#   ✓ Saved → data/ETTm1.csv  (10118 KB, 0.5s)
#   ✓ ETTm1 verified: shape=(69680, 8), columns=['date', 'HUFL', 'HULL', 'MUFL', 'MULL', 'LUFL', 'LULL', 'OT']
#
# [ETTm2]
#   Downloading ETTm2: 15-min ETT — station 2 (69,680 rows)
#   Source: https://raw.githubusercontent.com/zhouhaoyi/ETDataset/main/ETT-small/ETTm2.csv
#   [████████████████████] 100%  (9456 / 9450 KB)
#   ✓ Saved → data/ETTm2.csv  (9450 KB, 0.6s)
#   ✓ ETTm2 verified: shape=(69680, 8), columns=['date', 'HUFL', 'HULL', 'MUFL', 'MULL', 'LUFL', 'LULL', 'OT']
#
# ============================================================
# ✓ All downloads complete. Data ready in: /content/Time-Series-Library/data
#
# Next step:
#   uv run check-data

# %%
# !uv run check-data
# Out:
# ============================================================
# Data Pipeline Check — ETTh1 Forecasting
# ============================================================
#   ✓ train | batch_x: (32, 96, 7)  batch_y: (32, 144, 7)  x_mark: (32, 96, 4)  y_mark: (32, 144, 4)
#   ✓ val   | batch_x: (32, 96, 7)  batch_y: (32, 144, 7)  x_mark: (32, 96, 4)  y_mark: (32, 144, 4)
#   ✓ test  | batch_x: (32, 96, 7)  batch_y: (32, 144, 7)  x_mark: (32, 96, 4)  y_mark: (32, 144, 4)
# ============================================================
# ✓ Data pipeline check passed.

# %%
# !bash scripts/TimesNet/debug_ETTh1.sh
# Out:
# Device : cuda:0
# Model  : TimesNet
# Data   : ETTh1  seq=96  pred=96
# 2026-05-19 20:28:52.199 | INFO     | exp.exp_forecasting:_build_model:77 - Model built: TimesNet | params=9,394,005
# 2026-05-19 20:28:52.431 | INFO     | exp.exp_forecasting:train:127 - Loading datasets …
# 2026-05-19 20:28:52.534 | INFO     | exp.exp_forecasting:train:130 - Datasets loaded in 0.1s
# 2026-05-19 20:28:52.534 | INFO     | exp.exp_forecasting:_log_device_info:89 - GPU : Tesla T4 | 15.6 GB total
# 2026-05-19 20:28:52.534 | INFO     | exp.exp_forecasting:_log_loader_info:96 - Train split: 8,449 samples | 529 batches (batch_size=16)
# 2026-05-19 20:28:52.534 | INFO     | exp.exp_forecasting:_log_loader_info:96 - Val   split: 2,785 samples | 175 batches (batch_size=16)
# 2026-05-19 20:28:53.504 | INFO     | exp.exp_forecasting:train:142 - Training TimesNet on ETTh1 | pred_len=96 | epochs=1 | lr=1.00e-04 | device=cuda:0
# 2026-05-19 20:28:53.504 | INFO     | exp.exp_forecasting:train:147 - ------------------------------------------------------------
# 2026-05-19 20:32:31.392 | INFO     | exp.exp_forecasting:train:198 - Epoch 001/1 | train=0.3987 | val=0.7278 | lr=1.00e-04 | 217.9s [data=0.4s fwd/bwd=198.7s val=18.4s] | CUDA mem 0.17/1.70 GB
# 2026-05-19 20:32:31.461 | DEBUG    | utils.tools:save_checkpoint:82 - Checkpoint saved → checkpoints/TimesNet_ETTh1_forecasting_96/best_model.pth
# 2026-05-19 20:32:31.461 | DEBUG    | utils.tools:__call__:46 - EarlyStopping: initial checkpoint (val_loss=0.727759)
# 2026-05-19 20:32:31.461 | INFO     | exp.exp_forecasting:train:213 - ------------------------------------------------------------
# 2026-05-19 20:32:31.503 | DEBUG    | utils.tools:load_checkpoint:111 - Checkpoint loaded ← checkpoints/TimesNet_ETTh1_forecasting_96/best_model.pth
# 2026-05-19 20:32:31.503 | INFO     | exp.exp_forecasting:train:215 - Best model restored from checkpoints/TimesNet_ETTh1_forecasting_96/best_model.pth
# 2026-05-19 20:32:31.524 | INFO     | exp.exp_forecasting:test:224 - Starting test evaluation …
# 2026-05-19 20:32:31.559 | DEBUG    | utils.tools:load_checkpoint:111 - Checkpoint loaded ← checkpoints/TimesNet_ETTh1_forecasting_96/best_model.pth
# 2026-05-19 20:32:31.609 | INFO     | exp.exp_forecasting:_log_loader_info:96 - Test  split: 5,805 samples | 363 batches (batch_size=16)
# 2026-05-19 20:33:09.113 | INFO     | exp.exp_forecasting:test:251 - Test done in 37.5s | MSE=0.4872 | MAE=0.4741 | RMSE=0.6980 | MAPE=10.0694
# Results saved → results/TimesNet_ETTh1_forecasting_96_20260519_203309.json

# %%
# !bash scripts/TimesNet/forecast_ETTh1.sh
# Out:
# Device : cuda:0
# Model  : TimesNet
# Data   : ETTh1  seq=96  pred=96
# 2026-05-19 20:48:16.837 | INFO     | exp.exp_forecasting:_build_model:77 - Model built: TimesNet | params=9,394,005
# 2026-05-19 20:48:17.261 | INFO     | exp.exp_forecasting:train:127 - Loading datasets …
# 2026-05-19 20:48:17.425 | INFO     | exp.exp_forecasting:train:130 - Datasets loaded in 0.2s
# 2026-05-19 20:48:17.425 | INFO     | exp.exp_forecasting:_log_device_info:89 - GPU : Tesla T4 | 15.6 GB total
# 2026-05-19 20:48:17.425 | INFO     | exp.exp_forecasting:_log_loader_info:96 - Train split: 8,449 samples | 529 batches (batch_size=16)
# 2026-05-19 20:48:17.425 | INFO     | exp.exp_forecasting:_log_loader_info:96 - Val   split: 2,785 samples | 175 batches (batch_size=16)
# 2026-05-19 20:48:18.833 | INFO     | exp.exp_forecasting:train:142 - Training TimesNet on ETTh1 | pred_len=96 | epochs=10 | lr=1.00e-04 | device=cuda:0
# 2026-05-19 20:48:18.833 | INFO     | exp.exp_forecasting:train:147 - ------------------------------------------------------------
# Traceback (most recent call last):
#   File "/content/Time-Series-Library/run.py", line 166, in <module>
#     main()
#   File "/content/Time-Series-Library/run.py", line 158, in main
#     exp.train()
#   File "/content/Time-Series-Library/exp/exp_forecasting.py", line 179, in train
#     loss.backward()
#   File "/content/Time-Series-Library/.venv/lib/python3.12/site-packages/torch/_tensor.py", line 581, in backward
#     torch.autograd.backward(
#   File "/content/Time-Series-Library/.venv/lib/python3.12/site-packages/torch/autograd/__init__.py", line 347, in backward
#     _engine_run_backward(
#   File "/content/Time-Series-Library/.venv/lib/python3.12/site-packages/torch/autograd/graph.py", line 825, in _engine_run_backward
#     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt

# %%
# !bash scripts/TimeMixer/forecast_ETTh1.sh
# Out:
# Device : cuda:0
# Model  : TimeMixer
# Data   : ETTh1  seq=96  pred=96
# 2026-05-19 21:00:38.949 | INFO     | exp.exp_forecasting:_build_model:78 - Model built: TimeMixer | params=75,465
# 2026-05-19 21:00:39.158 | INFO     | exp.exp_forecasting:train:128 - Loading datasets …
# 2026-05-19 21:00:39.268 | INFO     | exp.exp_forecasting:train:131 - Datasets loaded in 0.1s
# 2026-05-19 21:00:39.268 | INFO     | exp.exp_forecasting:_log_device_info:90 - GPU : Tesla T4 | 15.6 GB total
# 2026-05-19 21:00:39.269 | INFO     | exp.exp_forecasting:_log_loader_info:97 - Train split: 8,449 samples | 529 batches (batch_size=16)
# 2026-05-19 21:00:39.269 | INFO     | exp.exp_forecasting:_log_loader_info:97 - Val   split: 2,785 samples | 175 batches (batch_size=16)
# 2026-05-19 21:00:42.998 | INFO     | exp.exp_forecasting:train:143 - Training TimeMixer on ETTh1 | pred_len=96 | epochs=10 | lr=1.00e-02 | device=cuda:0
# 2026-05-19 21:00:42.998 | INFO     | exp.exp_forecasting:train:148 - ------------------------------------------------------------
# 2026-05-19 21:01:00.285 | INFO     | exp.exp_forecasting:train:199 - Epoch 001/10 | train=0.3711 | val=0.7246 | lr=1.00e-02 | 17.3s [data=0.3s fwd/bwd=14.5s val=2.1s] | CUDA mem 0.02/0.08 GB
# 2026-05-19 21:01:00.298 | DEBUG    | utils.tools:save_checkpoint:82 - Checkpoint saved → checkpoints/TimeMixer_ETTh1_forecasting_96/best_model.pth
# 2026-05-19 21:01:00.298 | DEBUG    | utils.tools:__call__:46 - EarlyStopping: initial checkpoint (val_loss=0.724552)
# 2026-05-19 21:01:16.650 | INFO     | exp.exp_forecasting:train:199 - Epoch 002/10 | train=0.3492 | val=0.6961 | lr=1.00e-02 | 16.4s [data=0.3s fwd/bwd=14.1s val=1.6s] | CUDA mem 0.02/0.08 GB
# 2026-05-19 21:01:16.659 | DEBUG    | utils.tools:save_checkpoint:82 - Checkpoint saved → checkpoints/TimeMixer_ETTh1_forecasting_96/best_model.pth
# 2026-05-19 21:01:16.659 | DEBUG    | utils.tools:__call__:61 - EarlyStopping: improved (val_loss=0.696108) — checkpoint saved
# 2026-05-19 21:01:33.491 | INFO     | exp.exp_forecasting:train:199 - Epoch 003/10 | train=0.3385 | val=0.6931 | lr=1.00e-02 | 16.8s [data=0.3s fwd/bwd=14.5s val=1.7s] | CUDA mem 0.02/0.08 GB
# 2026-05-19 21:01:33.500 | DEBUG    | utils.tools:save_checkpoint:82 - Checkpoint saved → checkpoints/TimeMixer_ETTh1_forecasting_96/best_model.pth
# 2026-05-19 21:01:33.500 | DEBUG    | utils.tools:__call__:61 - EarlyStopping: improved (val_loss=0.693103) — checkpoint saved
# 2026-05-19 21:01:49.939 | INFO     | exp.exp_forecasting:train:199 - Epoch 004/10 | train=0.3314 | val=0.6882 | lr=1.00e-02 | 16.4s [data=0.3s fwd/bwd=14.2s val=1.7s] | CUDA mem 0.02/0.08 GB
# 2026-05-19 21:01:49.948 | DEBUG    | utils.tools:save_checkpoint:82 - Checkpoint saved → checkpoints/TimeMixer_ETTh1_forecasting_96/best_model.pth
# 2026-05-19 21:01:49.948 | DEBUG    | utils.tools:__call__:61 - EarlyStopping: improved (val_loss=0.688154) — checkpoint saved
# 2026-05-19 21:02:07.248 | INFO     | exp.exp_forecasting:train:199 - Epoch 005/10 | train=0.3236 | val=0.6819 | lr=1.00e-02 | 17.3s [data=0.3s fwd/bwd=14.6s val=2.0s] | CUDA mem 0.02/0.08 GB
# 2026-05-19 21:02:07.257 | DEBUG    | utils.tools:save_checkpoint:82 - Checkpoint saved → checkpoints/TimeMixer_ETTh1_forecasting_96/best_model.pth
# 2026-05-19 21:02:07.257 | DEBUG    | utils.tools:__call__:61 - EarlyStopping: improved (val_loss=0.681855) — checkpoint saved
# 2026-05-19 21:02:23.446 | INFO     | exp.exp_forecasting:train:199 - Epoch 006/10 | train=0.3178 | val=0.6885 | lr=1.00e-02 | 16.2s [data=0.3s fwd/bwd=13.9s val=1.6s] | CUDA mem 0.02/0.08 GB
# 2026-05-19 21:02:23.447 | INFO     | utils.tools:__call__:51 - EarlyStopping: no improvement for 1/3 epochs (val_loss=0.688498, best=0.681855)
# 2026-05-19 21:02:39.713 | INFO     | exp.exp_forecasting:train:199 - Epoch 007/10 | train=0.3119 | val=0.6864 | lr=1.00e-02 | 16.3s [data=0.3s fwd/bwd=13.9s val=1.7s] | CUDA mem 0.02/0.08 GB
# 2026-05-19 21:02:39.713 | INFO     | utils.tools:__call__:51 - EarlyStopping: no improvement for 2/3 epochs (val_loss=0.686352, best=0.681855)
# 2026-05-19 21:02:56.283 | INFO     | exp.exp_forecasting:train:199 - Epoch 008/10 | train=0.3070 | val=0.6945 | lr=1.00e-02 | 16.6s [data=0.3s fwd/bwd=14.2s val=1.8s] | CUDA mem 0.02/0.08 GB
# 2026-05-19 21:02:56.284 | INFO     | utils.tools:__call__:51 - EarlyStopping: no improvement for 3/3 epochs (val_loss=0.694473, best=0.681855)
# 2026-05-19 21:02:56.284 | INFO     | exp.exp_forecasting:train:211 - Early stopping at epoch 8 (patience=3).
# 2026-05-19 21:02:56.284 | INFO     | exp.exp_forecasting:train:214 - ------------------------------------------------------------
# 2026-05-19 21:02:56.315 | DEBUG    | utils.tools:load_checkpoint:111 - Checkpoint loaded ← checkpoints/TimeMixer_ETTh1_forecasting_96/best_model.pth
# 2026-05-19 21:02:56.315 | INFO     | exp.exp_forecasting:train:216 - Best model restored from checkpoints/TimeMixer_ETTh1_forecasting_96/best_model.pth
# 2026-05-19 21:02:56.345 | INFO     | exp.exp_forecasting:test:225 - Starting test evaluation …
# 2026-05-19 21:02:56.369 | DEBUG    | utils.tools:load_checkpoint:111 - Checkpoint loaded ← checkpoints/TimeMixer_ETTh1_forecasting_96/best_model.pth
# 2026-05-19 21:02:56.460 | INFO     | exp.exp_forecasting:_log_loader_info:97 - Test  split: 5,805 samples | 363 batches (batch_size=16)
# 2026-05-19 21:03:00.460 | INFO     | exp.exp_forecasting:test:252 - Test done in 4.0s | MSE=0.4759 | MAE=0.4597 | RMSE=0.6898 | MAPE=8.8901
# Results saved → results/TimeMixer_ETTh1_forecasting_96_20260519_210300.json

# %%
# !bash scripts/PatchTST/debug_ETTh1.sh
# Out:
# Device : cuda:0
# Model  : PatchTST
# Data   : ETTh1  seq=96  pred=96
# 2026-05-19 21:31:40.141 | INFO     | exp.exp_forecasting:_build_model:79 - Model built: PatchTST | params=548,846
# 2026-05-19 21:31:40.347 | INFO     | exp.exp_forecasting:train:129 - Loading datasets …
# 2026-05-19 21:31:40.456 | INFO     | exp.exp_forecasting:train:132 - Datasets loaded in 0.1s
# 2026-05-19 21:31:40.456 | INFO     | exp.exp_forecasting:_log_device_info:91 - GPU : Tesla T4 | 15.6 GB total
# 2026-05-19 21:31:40.456 | INFO     | exp.exp_forecasting:_log_loader_info:98 - Train split: 8,449 samples | 133 batches (batch_size=64)
# 2026-05-19 21:31:40.456 | INFO     | exp.exp_forecasting:_log_loader_info:98 - Val   split: 2,785 samples | 44 batches (batch_size=64)
# 2026-05-19 21:31:41.471 | INFO     | exp.exp_forecasting:train:144 - Training PatchTST on ETTh1 | pred_len=96 | epochs=1 | lr=1.00e-04 | device=cuda:0
# 2026-05-19 21:31:41.471 | INFO     | exp.exp_forecasting:train:149 - ------------------------------------------------------------
# 2026-05-19 21:31:45.658 | INFO     | exp.exp_forecasting:train:200 - Epoch 001/1 | train=0.4229 | val=0.7175 | lr=1.00e-04 | 4.2s [data=0.1s fwd/bwd=3.6s val=0.3s] | CUDA mem 0.03/0.31 GB
# 2026-05-19 21:31:45.667 | DEBUG    | utils.tools:save_checkpoint:82 - Checkpoint saved → checkpoints/PatchTST_ETTh1_forecasting_96/best_model.pth
# 2026-05-19 21:31:45.667 | DEBUG    | utils.tools:__call__:46 - EarlyStopping: initial checkpoint (val_loss=0.717474)
# 2026-05-19 21:31:45.667 | INFO     | exp.exp_forecasting:train:215 - ------------------------------------------------------------
# 2026-05-19 21:31:45.680 | DEBUG    | utils.tools:load_checkpoint:111 - Checkpoint loaded ← checkpoints/PatchTST_ETTh1_forecasting_96/best_model.pth
# 2026-05-19 21:31:45.680 | INFO     | exp.exp_forecasting:train:217 - Best model restored from checkpoints/PatchTST_ETTh1_forecasting_96/best_model.pth
# 2026-05-19 21:31:45.699 | INFO     | exp.exp_forecasting:test:226 - Starting test evaluation …
# 2026-05-19 21:31:45.712 | DEBUG    | utils.tools:load_checkpoint:111 - Checkpoint loaded ← checkpoints/PatchTST_ETTh1_forecasting_96/best_model.pth
# 2026-05-19 21:31:45.771 | INFO     | exp.exp_forecasting:_log_loader_info:98 - Test  split: 5,805 samples | 91 batches (batch_size=64)
# 2026-05-19 21:31:46.755 | INFO     | exp.exp_forecasting:test:253 - Test done in 1.0s | MSE=0.4941 | MAE=0.4646 | RMSE=0.7029 | MAPE=8.4371
# Results saved → results/PatchTST_ETTh1_forecasting_96_20260519_213146.json

# %%
# !bash scripts/PatchTST/forecast_ETTh1.sh
# Out:
# Device : cuda:0
# Model  : PatchTST
# Data   : ETTh1  seq=96  pred=96
# 2026-05-19 21:32:03.438 | INFO     | exp.exp_forecasting:_build_model:79 - Model built: PatchTST | params=548,846
# 2026-05-19 21:32:03.651 | INFO     | exp.exp_forecasting:train:129 - Loading datasets …
# 2026-05-19 21:32:03.770 | INFO     | exp.exp_forecasting:train:132 - Datasets loaded in 0.1s
# 2026-05-19 21:32:03.771 | INFO     | exp.exp_forecasting:_log_device_info:91 - GPU : Tesla T4 | 15.6 GB total
# 2026-05-19 21:32:03.771 | INFO     | exp.exp_forecasting:_log_loader_info:98 - Train split: 8,449 samples | 133 batches (batch_size=64)
# 2026-05-19 21:32:03.771 | INFO     | exp.exp_forecasting:_log_loader_info:98 - Val   split: 2,785 samples | 44 batches (batch_size=64)
# 2026-05-19 21:32:04.878 | INFO     | exp.exp_forecasting:train:144 - Training PatchTST on ETTh1 | pred_len=96 | epochs=100 | lr=1.00e-04 | device=cuda:0
# 2026-05-19 21:32:04.878 | INFO     | exp.exp_forecasting:train:149 - ------------------------------------------------------------
# 2026-05-19 21:32:09.114 | INFO     | exp.exp_forecasting:train:200 - Epoch 001/100 | train=0.4229 | val=0.7175 | lr=1.00e-04 | 4.2s [data=0.1s fwd/bwd=3.6s val=0.4s] | CUDA mem 0.03/0.31 GB
# 2026-05-19 21:32:09.125 | DEBUG    | utils.tools:save_checkpoint:82 - Checkpoint saved → checkpoints/PatchTST_ETTh1_forecasting_96/best_model.pth
# 2026-05-19 21:32:09.125 | DEBUG    | utils.tools:__call__:46 - EarlyStopping: initial checkpoint (val_loss=0.717474)
# 2026-05-19 21:32:13.301 | INFO     | exp.exp_forecasting:train:200 - Epoch 002/100 | train=0.3754 | val=0.7103 | lr=1.00e-04 | 4.2s [data=0.2s fwd/bwd=3.4s val=0.5s] | CUDA mem 0.03/0.31 GB
# 2026-05-19 21:32:13.316 | DEBUG    | utils.tools:save_checkpoint:82 - Checkpoint saved → checkpoints/PatchTST_ETTh1_forecasting_96/best_model.pth
# 2026-05-19 21:32:13.316 | DEBUG    | utils.tools:__call__:61 - EarlyStopping: improved (val_loss=0.710337) — checkpoint saved
# 2026-05-19 21:32:17.252 | INFO     | exp.exp_forecasting:train:200 - Epoch 003/100 | train=0.3674 | val=0.6984 | lr=1.00e-04 | 3.9s [data=0.1s fwd/bwd=3.3s val=0.3s] | CUDA mem 0.03/0.31 GB
# 2026-05-19 21:32:17.261 | DEBUG    | utils.tools:save_checkpoint:82 - Checkpoint saved → checkpoints/PatchTST_ETTh1_forecasting_96/best_model.pth
# 2026-05-19 21:32:17.261 | DEBUG    | utils.tools:__call__:61 - EarlyStopping: improved (val_loss=0.698354) — checkpoint saved
# 2026-05-19 21:32:21.067 | INFO     | exp.exp_forecasting:train:200 - Epoch 004/100 | train=0.3614 | val=0.6961 | lr=1.00e-04 | 3.8s [data=0.1s fwd/bwd=3.2s val=0.3s] | CUDA mem 0.03/0.31 GB
# 2026-05-19 21:32:21.076 | DEBUG    | utils.tools:save_checkpoint:82 - Checkpoint saved → checkpoints/PatchTST_ETTh1_forecasting_96/best_model.pth
# 2026-05-19 21:32:21.076 | DEBUG    | utils.tools:__call__:61 - EarlyStopping: improved (val_loss=0.696148) — checkpoint saved
# 2026-05-19 21:32:25.144 | INFO     | exp.exp_forecasting:train:200 - Epoch 005/100 | train=0.3564 | val=0.6931 | lr=1.00e-04 | 4.1s [data=0.1s fwd/bwd=3.3s val=0.5s] | CUDA mem 0.03/0.31 GB
# 2026-05-19 21:32:25.156 | DEBUG    | utils.tools:save_checkpoint:82 - Checkpoint saved → checkpoints/PatchTST_ETTh1_forecasting_96/best_model.pth
# 2026-05-19 21:32:25.157 | DEBUG    | utils.tools:__call__:61 - EarlyStopping: improved (val_loss=0.693121) — checkpoint saved
# 2026-05-19 21:32:29.130 | INFO     | exp.exp_forecasting:train:200 - Epoch 006/100 | train=0.3537 | val=0.6958 | lr=1.00e-04 | 4.0s [data=0.2s fwd/bwd=3.3s val=0.3s] | CUDA mem 0.03/0.31 GB
# 2026-05-19 21:32:29.130 | INFO     | utils.tools:__call__:51 - EarlyStopping: no improvement for 1/10 epochs (val_loss=0.695845, best=0.693121)
# 2026-05-19 21:32:32.956 | INFO     | exp.exp_forecasting:train:200 - Epoch 007/100 | train=0.3492 | val=0.6946 | lr=1.00e-04 | 3.8s [data=0.1s fwd/bwd=3.2s val=0.4s] | CUDA mem 0.03/0.31 GB
# 2026-05-19 21:32:32.956 | INFO     | utils.tools:__call__:51 - EarlyStopping: no improvement for 2/10 epochs (val_loss=0.694623, best=0.693121)
# 2026-05-19 21:32:36.894 | INFO     | exp.exp_forecasting:train:200 - Epoch 008/100 | train=0.3465 | val=0.7186 | lr=1.00e-04 | 3.9s [data=0.1s fwd/bwd=3.3s val=0.4s] | CUDA mem 0.03/0.31 GB
# 2026-05-19 21:32:36.894 | INFO     | utils.tools:__call__:51 - EarlyStopping: no improvement for 3/10 epochs (val_loss=0.718579, best=0.693121)
# 2026-05-19 21:32:41.029 | INFO     | exp.exp_forecasting:train:200 - Epoch 009/100 | train=0.3436 | val=0.6959 | lr=5.00e-05 | 4.1s [data=0.2s fwd/bwd=3.4s val=0.3s] | CUDA mem 0.03/0.31 GB
# 2026-05-19 21:32:41.029 | INFO     | utils.tools:__call__:51 - EarlyStopping: no improvement for 4/10 epochs (val_loss=0.695903, best=0.693121)
# 2026-05-19 21:32:44.890 | INFO     | exp.exp_forecasting:train:200 - Epoch 010/100 | train=0.3420 | val=0.6998 | lr=5.00e-05 | 3.9s [data=0.1s fwd/bwd=3.3s val=0.3s] | CUDA mem 0.03/0.31 GB
# 2026-05-19 21:32:44.890 | INFO     | utils.tools:__call__:51 - EarlyStopping: no improvement for 5/10 epochs (val_loss=0.699806, best=0.693121)
# 2026-05-19 21:32:48.791 | INFO     | exp.exp_forecasting:train:200 - Epoch 011/100 | train=0.3449 | val=0.7001 | lr=5.00e-05 | 3.9s [data=0.1s fwd/bwd=3.3s val=0.3s] | CUDA mem 0.03/0.31 GB
# 2026-05-19 21:32:48.791 | INFO     | utils.tools:__call__:51 - EarlyStopping: no improvement for 6/10 epochs (val_loss=0.700075, best=0.693121)
# 2026-05-19 21:32:52.949 | INFO     | exp.exp_forecasting:train:200 - Epoch 012/100 | train=0.3385 | val=0.7030 | lr=2.50e-05 | 4.2s [data=0.2s fwd/bwd=3.4s val=0.4s] | CUDA mem 0.03/0.31 GB
# 2026-05-19 21:32:52.949 | INFO     | utils.tools:__call__:51 - EarlyStopping: no improvement for 7/10 epochs (val_loss=0.702975, best=0.693121)
# 2026-05-19 21:32:56.839 | INFO     | exp.exp_forecasting:train:200 - Epoch 013/100 | train=0.3401 | val=0.7048 | lr=2.50e-05 | 3.9s [data=0.1s fwd/bwd=3.3s val=0.4s] | CUDA mem 0.03/0.31 GB
# 2026-05-19 21:32:56.840 | INFO     | utils.tools:__call__:51 - EarlyStopping: no improvement for 8/10 epochs (val_loss=0.704808, best=0.693121)
# 2026-05-19 21:33:00.744 | INFO     | exp.exp_forecasting:train:200 - Epoch 014/100 | train=0.3363 | val=0.7023 | lr=2.50e-05 | 3.9s [data=0.1s fwd/bwd=3.3s val=0.3s] | CUDA mem 0.03/0.31 GB
# 2026-05-19 21:33:00.745 | INFO     | utils.tools:__call__:51 - EarlyStopping: no improvement for 9/10 epochs (val_loss=0.702290, best=0.693121)
# 2026-05-19 21:33:04.986 | INFO     | exp.exp_forecasting:train:200 - Epoch 015/100 | train=0.3364 | val=0.7047 | lr=1.25e-05 | 4.2s [data=0.2s fwd/bwd=3.4s val=0.5s] | CUDA mem 0.03/0.31 GB
# 2026-05-19 21:33:04.986 | INFO     | utils.tools:__call__:51 - EarlyStopping: no improvement for 10/10 epochs (val_loss=0.704691, best=0.693121)
# 2026-05-19 21:33:04.986 | INFO     | exp.exp_forecasting:train:212 - Early stopping at epoch 15 (patience=10).
# 2026-05-19 21:33:04.986 | INFO     | exp.exp_forecasting:train:215 - ------------------------------------------------------------
# 2026-05-19 21:33:05.005 | DEBUG    | utils.tools:load_checkpoint:111 - Checkpoint loaded ← checkpoints/PatchTST_ETTh1_forecasting_96/best_model.pth
# 2026-05-19 21:33:05.005 | INFO     | exp.exp_forecasting:train:217 - Best model restored from checkpoints/PatchTST_ETTh1_forecasting_96/best_model.pth
# 2026-05-19 21:33:05.038 | INFO     | exp.exp_forecasting:test:226 - Starting test evaluation …
# 2026-05-19 21:33:05.056 | DEBUG    | utils.tools:load_checkpoint:111 - Checkpoint loaded ← checkpoints/PatchTST_ETTh1_forecasting_96/best_model.pth
# 2026-05-19 21:33:05.145 | INFO     | exp.exp_forecasting:_log_loader_info:98 - Test  split: 5,805 samples | 91 batches (batch_size=64)
# 2026-05-19 21:33:06.108 | INFO     | exp.exp_forecasting:test:253 - Test done in 1.0s | MSE=0.4561 | MAE=0.4491 | RMSE=0.6753 | MAPE=8.6165
# Results saved → results/PatchTST_ETTh1_forecasting_96_20260519_213306.json
