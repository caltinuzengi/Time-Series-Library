# %%
# !nvidia-smi
# Out:
# Tue May 19 19:14:52 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import torch
print(torch.cuda.is_available())      # True
print(torch.cuda.get_device_name(0))
# Out:
# True
# Tesla T4

# %%
# !git clone https://github.com/caltinuzengi/Time-Series-Library.git
# %cd Time-Series-Library/
# Out:
# Cloning into 'Time-Series-Library'...
# remote: Enumerating objects: 101, done.
# remote: Counting objects: 100% (101/101), done.
# remote: Compressing objects: 100% (69/69), done.
# remote: Total 101 (delta 35), reused 82 (delta 19), pack-reused 0 (from 0)
# Receiving objects: 100% (101/101), 162.76 KiB | 8.14 MiB/s, done.
# Resolving deltas: 100% (35/35), done.
# /content/Time-Series-Library

# %%
# !git pull
# Out:
# Already up to date.

# %%
# !uv sync
# Out:
# Using CPython 3.12.13 interpreter at: /usr/bin/python3
# Creating virtual environment at: .venv
# Resolved 160 packages in 13ms
# Prepared 63 packages in 1m 04s
# Installed 63 packages in 820ms
#  + absl-py==2.4.0
#  + antlr4-python3-runtime==4.9.3
#  + axial-positional-embedding==0.3.12
#  + colt5-attention==0.11.1
#  + contourpy==1.3.3
#  + cycler==0.12.1
#  + einops==0.8.2
#  + filelock==3.25.2
#  + fonttools==4.62.0
#  + fsspec==2026.2.0
#  + grpcio==1.78.0
#  + hyper-connections==0.4.9
#  + jinja2==3.1.6
#  + joblib==1.5.3
#  + kiwisolver==1.5.0
#  + local-attention==1.11.2
#  + loguru==0.7.3
#  + markdown==3.10.2
#  + markupsafe==3.0.3
#  + matplotlib==3.10.8
#  + mpmath==1.3.0
#  + networkx==3.6.1
#  + numpy==2.4.3
#  + nvidia-cublas-cu12==12.1.3.1
#  + nvidia-cuda-cupti-cu12==12.1.105
#  + nvidia-cuda-nvrtc-cu12==12.1.105
#  + nvidia-cuda-runtime-cu12==12.1.105
#  + nvidia-cudnn-cu12==9.1.0.70
#  + nvidia-cufft-cu12==11.0.2.54
#  + nvidia-curand-cu12==10.3.2.106
#  + nvidia-cusolver-cu12==11.4.5.107
#  + nvidia-cusparse-cu12==12.1.0.106
#  + nvidia-nccl-cu12==2.21.5
#  + nvidia-nvjitlink-cu12==12.9.86
#  + nvidia-nvtx-cu12==12.1.105
#  + omegaconf==2.3.0
#  + packaging==26.0
#  + pandas==3.0.1
#  + pillow==12.1.1
#  + product-key-memory==0.3.0
#  + protobuf==7.34.0
#  + pyparsing==3.3.2
#  + python-dateutil==2.9.0.post0
#  + pyyaml==6.0.3
#  + reformer-pytorch==1.4.4
#  + scikit-learn==1.8.0
#  + scipy==1.17.1
#  + seaborn==0.13.2
#  + setuptools==82.0.1
#  + six==1.17.0
#  + sympy==1.13.1
#  + tensorboard==2.20.0
#  + tensorboard-data-server==0.7.2
#  + threadpoolctl==3.6.0
#  + time-series-library==0.1.0 (from file:///content/Time-Series-Library)
#  + torch==2.5.1+cu121
#  + torch-einops-utils==0.0.30
#  + torchaudio==2.5.1+cu121
#  + torchvision==0.20.1+cu121
#  + tqdm==4.67.3
#  + triton==3.1.0
#  + typing-extensions==4.15.0
#  + werkzeug==3.1.6

# %%
# !uv run download-data
# Out:
# ============================================================
# ETT Dataset Downloader
# Source : github.com/zhouhaoyi/ETDataset (Informer AAAI 2021)
# Dest   : /content/Time-Series-Library/data
# ============================================================
#
# [ETTh1]
#   Downloading ETTh1: Hourly ETT — station 1 (17,420 rows)
#   Source: https://raw.githubusercontent.com/zhouhaoyi/ETDataset/main/ETT-small/ETTh1.csv
#   [████████████████████] 100%  (2536 / 2529 KB)
#   ✓ Saved → data/ETTh1.csv  (2529 KB, 0.3s)
#   ✓ ETTh1 verified: shape=(17420, 8), columns=['date', 'HUFL', 'HULL', 'MUFL', 'MULL', 'LUFL', 'LULL', 'OT']
#
# [ETTh2]
#   Downloading ETTh2: Hourly ETT — station 2 (17,420 rows)
#   Source: https://raw.githubusercontent.com/zhouhaoyi/ETDataset/main/ETT-small/ETTh2.csv
#   [████████████████████] 100%  (2368 / 2361 KB)
#   ✓ Saved → data/ETTh2.csv  (2361 KB, 0.4s)
#   ✓ ETTh2 verified: shape=(17420, 8), columns=['date', 'HUFL', 'HULL', 'MUFL', 'MULL', 'LUFL', 'LULL', 'OT']
#
# [ETTm1]
#   Downloading ETTm1: 15-min ETT — station 1 (69,680 rows)
#   Source: https://raw.githubusercontent.com/zhouhaoyi/ETDataset/main/ETT-small/ETTm1.csv
#   [████████████████████] 100%  (10120 / 10118 KB)
#   ✓ Saved → data/ETTm1.csv  (10118 KB, 0.7s)
#   ✓ ETTm1 verified: shape=(69680, 8), columns=['date', 'HUFL', 'HULL', 'MUFL', 'MULL', 'LUFL', 'LULL', 'OT']
#
# [ETTm2]
#   Downloading ETTm2: 15-min ETT — station 2 (69,680 rows)
#   Source: https://raw.githubusercontent.com/zhouhaoyi/ETDataset/main/ETT-small/ETTm2.csv
#   [████████████████████] 100%  (9456 / 9450 KB)
#   ✓ Saved → data/ETTm2.csv  (9450 KB, 0.5s)
#   ✓ ETTm2 verified: shape=(69680, 8), columns=['date', 'HUFL', 'HULL', 'MUFL', 'MULL', 'LUFL', 'LULL', 'OT']
#
# ============================================================
# ✓ All downloads complete. Data ready in: /content/Time-Series-Library/data
#
# Next step:
#   uv run check-data

# %%
# !bash scripts/TimesNet/debug_ETTh1.sh
# Out:
# Device : cuda:0
# Model  : TimesNet
# Data   : ETTh1  seq=96  pred=96
# 2026-05-19 19:16:41.954 | INFO     | exp.exp_forecasting:_build_model:77 - Model built: TimesNet | params=1,183,381
# 2026-05-19 19:16:42.196 | INFO     | exp.exp_forecasting:train:127 - Loading datasets …
# 2026-05-19 19:16:42.320 | INFO     | exp.exp_forecasting:train:130 - Datasets loaded in 0.1s
# 2026-05-19 19:16:42.320 | INFO     | exp.exp_forecasting:_log_device_info:89 - GPU : Tesla T4 | 15.6 GB total
# 2026-05-19 19:16:42.320 | INFO     | exp.exp_forecasting:_log_loader_info:96 - Train split: 8,449 samples | 529 batches (batch_size=16)
# 2026-05-19 19:16:42.320 | INFO     | exp.exp_forecasting:_log_loader_info:96 - Val   split: 2,785 samples | 175 batches (batch_size=16)
# 2026-05-19 19:16:47.594 | INFO     | exp.exp_forecasting:train:142 - Training TimesNet on ETTh1 | pred_len=96 | epochs=1 | lr=1.00e-04 | device=cuda:0
# 2026-05-19 19:16:47.594 | INFO     | exp.exp_forecasting:train:147 - ------------------------------------------------------------
# 2026-05-19 19:17:35.114 | INFO     | exp.exp_forecasting:train:198 - Epoch 001/1 | train=0.5361 | val=1.0934 | lr=1.00e-04 | 47.5s [data=0.4s fwd/bwd=42.2s val=4.6s] | CUDA mem 0.04/0.15 GB
# 2026-05-19 19:17:35.127 | DEBUG    | utils.tools:save_checkpoint:82 - Checkpoint saved → checkpoints/TimesNet_ETTh1_forecasting_96/best_model.pth
# 2026-05-19 19:17:35.127 | DEBUG    | utils.tools:__call__:46 - EarlyStopping: initial checkpoint (val_loss=1.093439)
# 2026-05-19 19:17:35.127 | INFO     | exp.exp_forecasting:train:213 - ------------------------------------------------------------
# 2026-05-19 19:17:35.147 | DEBUG    | utils.tools:load_checkpoint:111 - Checkpoint loaded ← checkpoints/TimesNet_ETTh1_forecasting_96/best_model.pth
# 2026-05-19 19:17:35.147 | INFO     | exp.exp_forecasting:train:215 - Best model restored from checkpoints/TimesNet_ETTh1_forecasting_96/best_model.pth
# 2026-05-19 19:17:35.165 | INFO     | exp.exp_forecasting:test:224 - Starting test evaluation …
# 2026-05-19 19:17:35.191 | DEBUG    | utils.tools:load_checkpoint:111 - Checkpoint loaded ← checkpoints/TimesNet_ETTh1_forecasting_96/best_model.pth
# 2026-05-19 19:17:35.252 | INFO     | exp.exp_forecasting:_log_loader_info:96 - Test  split: 5,805 samples | 363 batches (batch_size=16)
# 2026-05-19 19:17:45.182 | INFO     | exp.exp_forecasting:test:251 - Test done in 9.9s | MSE=0.8649 | MAE=0.6411 | RMSE=0.9300 | MAPE=11.7587
# Results saved → results/TimesNet_ETTh1_forecasting_96_20260519_191745.json

# %%
# !bash scripts/TimesNet/forecast_ETTh1.sh
# Out:
# Device : cuda:0
# Model  : TimesNet
# Data   : ETTh1  seq=96  pred=96
# 2026-05-19 19:18:51.868 | INFO     | exp.exp_forecasting:_build_model:77 - Model built: TimesNet | params=1,183,381
# 2026-05-19 19:18:52.083 | INFO     | exp.exp_forecasting:train:127 - Loading datasets …
# 2026-05-19 19:18:52.201 | INFO     | exp.exp_forecasting:train:130 - Datasets loaded in 0.1s
# 2026-05-19 19:18:52.201 | INFO     | exp.exp_forecasting:_log_device_info:89 - GPU : Tesla T4 | 15.6 GB total
# 2026-05-19 19:18:52.201 | INFO     | exp.exp_forecasting:_log_loader_info:96 - Train split: 8,449 samples | 265 batches (batch_size=32)
# 2026-05-19 19:18:52.202 | INFO     | exp.exp_forecasting:_log_loader_info:96 - Val   split: 2,785 samples | 88 batches (batch_size=32)
# 2026-05-19 19:18:53.227 | INFO     | exp.exp_forecasting:train:142 - Training TimesNet on ETTh1 | pred_len=96 | epochs=10 | lr=1.00e-04 | device=cuda:0
# 2026-05-19 19:18:53.227 | INFO     | exp.exp_forecasting:train:147 - ------------------------------------------------------------
# 2026-05-19 19:19:33.386 | INFO     | exp.exp_forecasting:train:198 - Epoch 001/10 | train=0.5449 | val=1.1043 | lr=1.00e-04 | 40.2s [data=0.3s fwd/bwd=35.7s val=4.0s] | CUDA mem 0.04/0.29 GB
# 2026-05-19 19:19:33.406 | DEBUG    | utils.tools:save_checkpoint:82 - Checkpoint saved → checkpoints/TimesNet_ETTh1_forecasting_96/best_model.pth
# 2026-05-19 19:19:33.406 | DEBUG    | utils.tools:__call__:46 - EarlyStopping: initial checkpoint (val_loss=1.104285)
# 2026-05-19 19:20:14.557 | INFO     | exp.exp_forecasting:train:198 - Epoch 002/10 | train=0.5218 | val=1.0949 | lr=1.00e-04 | 41.2s [data=0.3s fwd/bwd=36.5s val=4.1s] | CUDA mem 0.04/0.29 GB
# 2026-05-19 19:20:14.573 | DEBUG    | utils.tools:save_checkpoint:82 - Checkpoint saved → checkpoints/TimesNet_ETTh1_forecasting_96/best_model.pth
# 2026-05-19 19:20:14.574 | DEBUG    | utils.tools:__call__:61 - EarlyStopping: improved (val_loss=1.094915) — checkpoint saved
# 2026-05-19 19:20:56.786 | INFO     | exp.exp_forecasting:train:198 - Epoch 003/10 | train=0.5198 | val=1.0926 | lr=1.00e-04 | 42.2s [data=0.2s fwd/bwd=37.6s val=4.1s] | CUDA mem 0.04/0.29 GB
# 2026-05-19 19:20:56.808 | DEBUG    | utils.tools:save_checkpoint:82 - Checkpoint saved → checkpoints/TimesNet_ETTh1_forecasting_96/best_model.pth
# 2026-05-19 19:20:56.808 | DEBUG    | utils.tools:__call__:61 - EarlyStopping: improved (val_loss=1.092561) — checkpoint saved
# 2026-05-19 19:21:38.828 | INFO     | exp.exp_forecasting:train:198 - Epoch 004/10 | train=0.5119 | val=1.0814 | lr=1.00e-04 | 42.0s [data=0.3s fwd/bwd=37.2s val=4.2s] | CUDA mem 0.04/0.29 GB
# 2026-05-19 19:21:38.843 | DEBUG    | utils.tools:save_checkpoint:82 - Checkpoint saved → checkpoints/TimesNet_ETTh1_forecasting_96/best_model.pth
# 2026-05-19 19:21:38.843 | DEBUG    | utils.tools:__call__:61 - EarlyStopping: improved (val_loss=1.081428) — checkpoint saved
# 2026-05-19 19:22:20.874 | INFO     | exp.exp_forecasting:train:198 - Epoch 005/10 | train=0.5102 | val=1.0802 | lr=1.00e-04 | 42.0s [data=0.2s fwd/bwd=37.3s val=4.1s] | CUDA mem 0.04/0.29 GB
# 2026-05-19 19:22:20.889 | DEBUG    | utils.tools:save_checkpoint:82 - Checkpoint saved → checkpoints/TimesNet_ETTh1_forecasting_96/best_model.pth
# 2026-05-19 19:22:20.890 | DEBUG    | utils.tools:__call__:61 - EarlyStopping: improved (val_loss=1.080158) — checkpoint saved
# 2026-05-19 19:23:02.726 | INFO     | exp.exp_forecasting:train:198 - Epoch 006/10 | train=0.5080 | val=1.0824 | lr=1.00e-04 | 41.8s [data=0.2s fwd/bwd=37.2s val=4.1s] | CUDA mem 0.04/0.29 GB
# 2026-05-19 19:23:02.726 | INFO     | utils.tools:__call__:51 - EarlyStopping: no improvement for 1/3 epochs (val_loss=1.082414, best=1.080158)
# 2026-05-19 19:23:44.589 | INFO     | exp.exp_forecasting:train:198 - Epoch 007/10 | train=0.5085 | val=1.0818 | lr=1.00e-04 | 41.9s [data=0.2s fwd/bwd=37.3s val=4.1s] | CUDA mem 0.04/0.29 GB
# 2026-05-19 19:23:44.589 | INFO     | utils.tools:__call__:51 - EarlyStopping: no improvement for 2/3 epochs (val_loss=1.081805, best=1.080158)
# 2026-05-19 19:24:26.504 | INFO     | exp.exp_forecasting:train:198 - Epoch 008/10 | train=0.5061 | val=1.0763 | lr=1.00e-04 | 41.9s [data=0.2s fwd/bwd=37.2s val=4.2s] | CUDA mem 0.04/0.29 GB
# 2026-05-19 19:24:26.524 | DEBUG    | utils.tools:save_checkpoint:82 - Checkpoint saved → checkpoints/TimesNet_ETTh1_forecasting_96/best_model.pth
# 2026-05-19 19:24:26.525 | DEBUG    | utils.tools:__call__:61 - EarlyStopping: improved (val_loss=1.076256) — checkpoint saved
# 2026-05-19 19:25:08.561 | INFO     | exp.exp_forecasting:train:198 - Epoch 009/10 | train=0.5045 | val=1.0764 | lr=1.00e-04 | 42.0s [data=0.2s fwd/bwd=37.2s val=4.2s] | CUDA mem 0.04/0.29 GB
# 2026-05-19 19:25:08.561 | INFO     | utils.tools:__call__:51 - EarlyStopping: no improvement for 1/3 epochs (val_loss=1.076421, best=1.076256)
# 2026-05-19 19:25:50.334 | INFO     | exp.exp_forecasting:train:198 - Epoch 010/10 | train=0.5051 | val=1.0760 | lr=1.00e-04 | 41.8s [data=0.2s fwd/bwd=37.2s val=4.1s] | CUDA mem 0.04/0.29 GB
# 2026-05-19 19:25:50.349 | DEBUG    | utils.tools:save_checkpoint:82 - Checkpoint saved → checkpoints/TimesNet_ETTh1_forecasting_96/best_model.pth
# 2026-05-19 19:25:50.349 | DEBUG    | utils.tools:__call__:61 - EarlyStopping: improved (val_loss=1.075950) — checkpoint saved
# 2026-05-19 19:25:50.349 | INFO     | exp.exp_forecasting:train:213 - ------------------------------------------------------------
# 2026-05-19 19:25:50.367 | DEBUG    | utils.tools:load_checkpoint:111 - Checkpoint loaded ← checkpoints/TimesNet_ETTh1_forecasting_96/best_model.pth
# 2026-05-19 19:25:50.367 | INFO     | exp.exp_forecasting:train:215 - Best model restored from checkpoints/TimesNet_ETTh1_forecasting_96/best_model.pth
# 2026-05-19 19:25:50.400 | INFO     | exp.exp_forecasting:test:224 - Starting test evaluation …
# 2026-05-19 19:25:50.428 | DEBUG    | utils.tools:load_checkpoint:111 - Checkpoint loaded ← checkpoints/TimesNet_ETTh1_forecasting_96/best_model.pth
# 2026-05-19 19:25:50.483 | INFO     | exp.exp_forecasting:_log_loader_info:96 - Test  split: 5,805 samples | 182 batches (batch_size=32)
# 2026-05-19 19:25:59.167 | INFO     | exp.exp_forecasting:test:251 - Test done in 8.7s | MSE=0.8423 | MAE=0.6289 | RMSE=0.9177 | MAPE=11.9476
# Results saved → results/TimesNet_ETTh1_forecasting_96_20260519_192559.json

# %%
# !bash scripts/TimesNet/forecast_ETTh1.sh
# Out:
# Device : cuda:0
# Model  : TimesNet
# Data   : ETTh1  seq=96  pred=96
# 2026-05-19 19:29:50.437 | INFO     | exp.exp_forecasting:_build_model:77 - Model built: TimesNet | params=1,183,381
# 2026-05-19 19:29:50.654 | INFO     | exp.exp_forecasting:train:127 - Loading datasets …
# 2026-05-19 19:29:50.761 | INFO     | exp.exp_forecasting:train:130 - Datasets loaded in 0.1s
# 2026-05-19 19:29:50.761 | INFO     | exp.exp_forecasting:_log_device_info:89 - GPU : Tesla T4 | 15.6 GB total
# 2026-05-19 19:29:50.761 | INFO     | exp.exp_forecasting:_log_loader_info:96 - Train split: 8,449 samples | 67 batches (batch_size=128)
# 2026-05-19 19:29:50.761 | INFO     | exp.exp_forecasting:_log_loader_info:96 - Val   split: 2,785 samples | 22 batches (batch_size=128)
# 2026-05-19 19:29:51.777 | INFO     | exp.exp_forecasting:train:142 - Training TimesNet on ETTh1 | pred_len=96 | epochs=20 | lr=1.00e-04 | device=cuda:0
# 2026-05-19 19:29:51.777 | INFO     | exp.exp_forecasting:train:147 - ------------------------------------------------------------
# 2026-05-19 19:30:26.488 | INFO     | exp.exp_forecasting:train:198 - Epoch 001/20 | train=0.5735 | val=1.1029 | lr=1.00e-04 | 34.7s [data=0.2s fwd/bwd=30.8s val=3.6s] | CUDA mem 0.04/0.81 GB
# 2026-05-19 19:30:26.505 | DEBUG    | utils.tools:save_checkpoint:82 - Checkpoint saved → checkpoints/TimesNet_ETTh1_forecasting_96/best_model.pth
# 2026-05-19 19:30:26.505 | DEBUG    | utils.tools:__call__:46 - EarlyStopping: initial checkpoint (val_loss=1.102901)
# 2026-05-19 19:31:01.840 | INFO     | exp.exp_forecasting:train:198 - Epoch 002/20 | train=0.5289 | val=1.1016 | lr=1.00e-04 | 35.3s [data=0.1s fwd/bwd=31.4s val=3.7s] | CUDA mem 0.04/0.81 GB
# 2026-05-19 19:31:01.856 | DEBUG    | utils.tools:save_checkpoint:82 - Checkpoint saved → checkpoints/TimesNet_ETTh1_forecasting_96/best_model.pth
# 2026-05-19 19:31:01.856 | DEBUG    | utils.tools:__call__:61 - EarlyStopping: improved (val_loss=1.101567) — checkpoint saved
# 2026-05-19 19:31:38.660 | INFO     | exp.exp_forecasting:train:198 - Epoch 003/20 | train=0.5362 | val=1.0909 | lr=1.00e-04 | 36.8s [data=0.1s fwd/bwd=32.7s val=3.8s] | CUDA mem 0.04/0.81 GB
# 2026-05-19 19:31:38.675 | DEBUG    | utils.tools:save_checkpoint:82 - Checkpoint saved → checkpoints/TimesNet_ETTh1_forecasting_96/best_model.pth
# 2026-05-19 19:31:38.675 | DEBUG    | utils.tools:__call__:61 - EarlyStopping: improved (val_loss=1.090919) — checkpoint saved
# 2026-05-19 19:32:15.339 | INFO     | exp.exp_forecasting:train:198 - Epoch 004/20 | train=0.5163 | val=1.0880 | lr=1.00e-04 | 36.7s [data=0.1s fwd/bwd=32.7s val=3.7s] | CUDA mem 0.04/0.81 GB
# 2026-05-19 19:32:15.353 | DEBUG    | utils.tools:save_checkpoint:82 - Checkpoint saved → checkpoints/TimesNet_ETTh1_forecasting_96/best_model.pth
# 2026-05-19 19:32:15.353 | DEBUG    | utils.tools:__call__:61 - EarlyStopping: improved (val_loss=1.088022) — checkpoint saved
# 2026-05-19 19:32:51.982 | INFO     | exp.exp_forecasting:train:198 - Epoch 005/20 | train=0.5162 | val=1.0801 | lr=1.00e-04 | 36.6s [data=0.1s fwd/bwd=32.5s val=3.8s] | CUDA mem 0.04/0.81 GB
# 2026-05-19 19:32:52.003 | DEBUG    | utils.tools:save_checkpoint:82 - Checkpoint saved → checkpoints/TimesNet_ETTh1_forecasting_96/best_model.pth
# 2026-05-19 19:32:52.003 | DEBUG    | utils.tools:__call__:61 - EarlyStopping: improved (val_loss=1.080072) — checkpoint saved
# 2026-05-19 19:33:28.686 | INFO     | exp.exp_forecasting:train:198 - Epoch 006/20 | train=0.5128 | val=1.0846 | lr=1.00e-04 | 36.7s [data=0.1s fwd/bwd=32.6s val=3.8s] | CUDA mem 0.04/0.81 GB
# 2026-05-19 19:33:28.686 | INFO     | utils.tools:__call__:51 - EarlyStopping: no improvement for 1/3 epochs (val_loss=1.084616, best=1.080072)
# 2026-05-19 19:34:05.308 | INFO     | exp.exp_forecasting:train:198 - Epoch 007/20 | train=0.5161 | val=1.0795 | lr=1.00e-04 | 36.6s [data=0.1s fwd/bwd=32.5s val=3.7s] | CUDA mem 0.04/0.81 GB
# 2026-05-19 19:34:05.328 | DEBUG    | utils.tools:save_checkpoint:82 - Checkpoint saved → checkpoints/TimesNet_ETTh1_forecasting_96/best_model.pth
# 2026-05-19 19:34:05.328 | DEBUG    | utils.tools:__call__:61 - EarlyStopping: improved (val_loss=1.079536) — checkpoint saved
# 2026-05-19 19:34:41.949 | INFO     | exp.exp_forecasting:train:198 - Epoch 008/20 | train=0.5109 | val=1.0810 | lr=1.00e-04 | 36.6s [data=0.1s fwd/bwd=32.5s val=3.7s] | CUDA mem 0.04/0.81 GB
# 2026-05-19 19:34:41.950 | INFO     | utils.tools:__call__:51 - EarlyStopping: no improvement for 1/3 epochs (val_loss=1.081045, best=1.079536)
# 2026-05-19 19:35:18.621 | INFO     | exp.exp_forecasting:train:198 - Epoch 009/20 | train=0.5090 | val=1.0764 | lr=1.00e-04 | 36.7s [data=0.1s fwd/bwd=32.6s val=3.7s] | CUDA mem 0.04/0.81 GB
# 2026-05-19 19:35:18.638 | DEBUG    | utils.tools:save_checkpoint:82 - Checkpoint saved → checkpoints/TimesNet_ETTh1_forecasting_96/best_model.pth
# 2026-05-19 19:35:18.638 | DEBUG    | utils.tools:__call__:61 - EarlyStopping: improved (val_loss=1.076423) — checkpoint saved
# 2026-05-19 19:35:55.367 | INFO     | exp.exp_forecasting:train:198 - Epoch 010/20 | train=0.5130 | val=1.0817 | lr=1.00e-04 | 36.7s [data=0.1s fwd/bwd=32.7s val=3.8s] | CUDA mem 0.04/0.81 GB
# 2026-05-19 19:35:55.368 | INFO     | utils.tools:__call__:51 - EarlyStopping: no improvement for 1/3 epochs (val_loss=1.081699, best=1.076423)
# 2026-05-19 19:36:32.114 | INFO     | exp.exp_forecasting:train:198 - Epoch 011/20 | train=0.5081 | val=1.0792 | lr=1.00e-04 | 36.7s [data=0.1s fwd/bwd=32.7s val=3.8s] | CUDA mem 0.04/0.81 GB
# 2026-05-19 19:36:32.114 | INFO     | utils.tools:__call__:51 - EarlyStopping: no improvement for 2/3 epochs (val_loss=1.079217, best=1.076423)
# 2026-05-19 19:37:08.776 | INFO     | exp.exp_forecasting:train:198 - Epoch 012/20 | train=0.5074 | val=1.0777 | lr=1.00e-04 | 36.7s [data=0.1s fwd/bwd=32.6s val=3.8s] | CUDA mem 0.04/0.81 GB
# 2026-05-19 19:37:08.777 | INFO     | utils.tools:__call__:51 - EarlyStopping: no improvement for 3/3 epochs (val_loss=1.077742, best=1.076423)
# 2026-05-19 19:37:08.777 | INFO     | exp.exp_forecasting:train:210 - Early stopping at epoch 12 (patience=3).
# 2026-05-19 19:37:08.777 | INFO     | exp.exp_forecasting:train:213 - ------------------------------------------------------------
# 2026-05-19 19:37:08.804 | DEBUG    | utils.tools:load_checkpoint:111 - Checkpoint loaded ← checkpoints/TimesNet_ETTh1_forecasting_96/best_model.pth
# 2026-05-19 19:37:08.804 | INFO     | exp.exp_forecasting:train:215 - Best model restored from checkpoints/TimesNet_ETTh1_forecasting_96/best_model.pth
# 2026-05-19 19:37:08.849 | INFO     | exp.exp_forecasting:test:224 - Starting test evaluation …
# 2026-05-19 19:37:08.872 | DEBUG    | utils.tools:load_checkpoint:111 - Checkpoint loaded ← checkpoints/TimesNet_ETTh1_forecasting_96/best_model.pth
# 2026-05-19 19:37:08.960 | INFO     | exp.exp_forecasting:_log_loader_info:96 - Test  split: 5,805 samples | 46 batches (batch_size=128)
# 2026-05-19 19:37:16.925 | INFO     | exp.exp_forecasting:test:251 - Test done in 8.0s | MSE=0.8523 | MAE=0.6378 | RMSE=0.9232 | MAPE=11.3909
# Results saved → results/TimesNet_ETTh1_forecasting_96_20260519_193716.json
