# %%
# !nvidia-smi
# Out:
# Tue May 19 16:00:56 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8             14W /   70W |       3MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import torch
print(torch.cuda.is_available())      # True
print(torch.cuda.get_device_name(0))
# Out:
# True
# Tesla T4

# %%
# !git clone https://github.com/caltinuzengi/Time-Series-Library.git
# %cd Time-Series-Library/
# Out:
# fatal: destination path 'Time-Series-Library' already exists and is not an empty directory.
# /content/Time-Series-Library

# %%
# !git pull
# Out:
# remote: Enumerating objects: 16, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 9 (delta 4), reused 9 (delta 4), pack-reused 0 (from 0)
# Unpacking objects: 100% (9/9), 3.27 KiB | 1.63 MiB/s, done.
# From https://github.com/caltinuzengi/Time-Series-Library
#    5628373..1b2899b  main       -> origin/main
# Updating 5628373..1b2899b
# Fast-forward
#  exp/exp_forecasting.py          | 129 +++++++++++++++++++++++++++++++---------
#  notebooks/01_experiments.ipynb  |  47 ++++++++-------
#  scripts/TimesNet/debug_ETTh1.sh |  33 ++++++++++
#  3 files changed, 159 insertions(+), 50 deletions(-)
#  create mode 100644 scripts/TimesNet/debug_ETTh1.sh

# %%
# !uv sync
# Out:
# Resolved 160 packages in 1ms
# Checked 63 packages in 1ms

# %%
# !uv run download-data
# Out:
# ============================================================
# ETT Dataset Downloader
# Source : github.com/zhouhaoyi/ETDataset (Informer AAAI 2021)
# Dest   : /content/Time-Series-Library/data
# ============================================================
#
# [ETTh1]
#   ✓ ETTh1 already exists (2529 KB) — skipping. Use --force to re-download.
#   ✓ ETTh1 verified: shape=(17420, 8), columns=['date', 'HUFL', 'HULL', 'MUFL', 'MULL', 'LUFL', 'LULL', 'OT']
#
# [ETTh2]
#   ✓ ETTh2 already exists (2361 KB) — skipping. Use --force to re-download.
#   ✓ ETTh2 verified: shape=(17420, 8), columns=['date', 'HUFL', 'HULL', 'MUFL', 'MULL', 'LUFL', 'LULL', 'OT']
#
# [ETTm1]
#   ✓ ETTm1 already exists (10118 KB) — skipping. Use --force to re-download.
#   ✓ ETTm1 verified: shape=(69680, 8), columns=['date', 'HUFL', 'HULL', 'MUFL', 'MULL', 'LUFL', 'LULL', 'OT']
#
# [ETTm2]
#   ✓ ETTm2 already exists (9450 KB) — skipping. Use --force to re-download.
#   ✓ ETTm2 verified: shape=(69680, 8), columns=['date', 'HUFL', 'HULL', 'MUFL', 'MULL', 'LUFL', 'LULL', 'OT']
#
# ============================================================
# ✓ All downloads complete. Data ready in: /content/Time-Series-Library/data
#
# Next step:
#   uv run check-data

# %%
# !bash scripts/TimesNet/debug_ETTh1.sh
# Out:
# Device : cuda:0
# Model  : TimesNet
# Data   : ETTh1  seq=96  pred=96
# 2026-05-19 16:35:55.049 | INFO     | exp.exp_forecasting:_build_model:75 - Model built: TimesNet | params=28,565
# 2026-05-19 16:35:55.261 | INFO     | exp.exp_forecasting:train:125 - Loading datasets …
# 2026-05-19 16:35:55.369 | INFO     | exp.exp_forecasting:train:128 - Datasets loaded in 0.1s
# 2026-05-19 16:35:55.370 | INFO     | exp.exp_forecasting:_log_device_info:87 - GPU : Tesla T4 | 15.6 GB total
# 2026-05-19 16:35:55.370 | INFO     | exp.exp_forecasting:_log_loader_info:94 - Train split: 8,449 samples | 529 batches (batch_size=16)
# 2026-05-19 16:35:55.370 | INFO     | exp.exp_forecasting:_log_loader_info:94 - Val   split: 2,785 samples | 175 batches (batch_size=16)
# 2026-05-19 16:35:56.482 | INFO     | exp.exp_forecasting:train:140 - Training TimesNet on ETTh1 | pred_len=96 | epochs=1 | lr=1.00e-04 | device=cuda:0
# 2026-05-19 16:35:56.482 | INFO     | exp.exp_forecasting:train:145 - ------------------------------------------------------------
# Traceback (most recent call last):
#   File "/content/Time-Series-Library/run.py", line 166, in <module>
#     main()
#   File "/content/Time-Series-Library/run.py", line 158, in main
#     exp.train()
#   File "/content/Time-Series-Library/exp/exp_forecasting.py", line 172, in train
#     loss.backward()
#   File "/content/Time-Series-Library/.venv/lib/python3.12/site-packages/torch/_tensor.py", line 581, in backward
#     torch.autograd.backward(
#   File "/content/Time-Series-Library/.venv/lib/python3.12/site-packages/torch/autograd/__init__.py", line 347, in backward
#     _engine_run_backward(
#   File "/content/Time-Series-Library/.venv/lib/python3.12/site-packages/torch/autograd/graph.py", line 825, in _engine_run_backward
#     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt

# %%
# !nvidia-smi -l 2
# Out:
# Tue May 19 16:39:19 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   66C    P8             12W /   70W |       3MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# Tue May 19 16:39:22 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   67C    P8             16W /   70W |       3MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# Tue May 19 16:39:24 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   67C    P8             16W /   70W |       3MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# !bash scripts/TimesNet/forecast_ETTh1.sh
# Out:
# Device : cuda:0
# Model  : TimesNet
# Data   : ETTh1  seq=96  pred=96
# 2026-05-19 16:14:26.642 | INFO     | exp.exp_forecasting:train:94 - Training TimesNet on ETTh1 | pred_len=96 | device=cuda:0
# 2026-05-19 16:29:26.048 | INFO     | exp.exp_forecasting:train:125 - Epoch 001/10 | train=0.5455 | val=1.1356 | lr=1.00e-04 | 899.4s
# 2026-05-19 16:29:26.053 | DEBUG    | utils.tools:save_checkpoint:82 - Checkpoint saved → checkpoints/TimesNet_ETTh1_forecasting_96/best_model.pth/best_model.pth
# 2026-05-19 16:29:26.053 | DEBUG    | utils.tools:__call__:46 - EarlyStopping: initial checkpoint (val_loss=1.135646)
# Traceback (most recent call last):
#   File "/content/Time-Series-Library/run.py", line 166, in <module>
#     main()
#   File "/content/Time-Series-Library/run.py", line 158, in main
#     exp.train()
#   File "/content/Time-Series-Library/exp/exp_forecasting.py", line 118, in train
#     train_losses.append(loss.item())
#                         ^^^^^^^^^^^
# KeyboardInterrupt
